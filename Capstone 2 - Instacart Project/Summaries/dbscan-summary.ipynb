# %% [markdown]
# # **Customer Segmentation using DBSCAN - Summary**

# %% [markdown]
# ## Introduction
# #### In this summary analysis, we segmented the customers (represented in the data by user_id) into distinct purchasing behavioral groups using DBSCAN, our last clustering method.  As noted this is important to see how our customers in the dataset are identified based on their purchasing behavior and how we can establish the forthcoming marketing promotions for them.

# %% [markdown]
# ## Data Preprocessing and Feature Creation
# #### Before applying the DBSCAN method, we performed the same essential data preprocessing steps such as scaling the features as we have done previously to ensure equal importance and handling missing values to maintain data integrity. Key features were selected based on their relevance to customer behavior, including order_dow_mean, order_hour_of_day_mean, time_between_purchases, and purchase_frequency.

# %% [markdown]
# ## Clustering Results
# #### Contrary to the other two methods that produced distinct clustering, DBSCAN wasn't able to produce reliable clustering from this dataset as there were too many noise points.  Visuals of the outcomes are below:
#
# #### DBSCAN Noise Point/eps value plot:
# ![image.png](attachment:image.png)
#
# #### DBSCAN Current best render of the Clustering with eps = 0.49, min_samples = 4:
# ![image-2.png](attachment:image-2.png)
#
# #### As you can see the vast majority of points are isolated in one cluster (the yellow).

# %% [markdown]
# ## Conclusion
# #### The DBSCAN method wasn't able to render reliable clusters from the data.  It is possible that further analysis could be done to yield results however it looks unlikely based on analysis performed thusfar.
